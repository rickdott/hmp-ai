# %%
from pathlib import Path
import os

# %%
checkpoint_glob = Path("./logs/").rglob("*.pt")

# %% [markdown]
# ONLY RUN THIS IF CHECKPOINTS IN LOGS FOLDER ARE TAKING UP TOO MUCH SPACE

# %%
for path in checkpoint_glob:
    print(path)
    os.remove(path)
# Out:
# logs/exp_formulation/20240111-115943_formulation-base_fold1/checkpoint.pt
# logs/exp_formulation/20240111-120029_formulation-base_fold2/checkpoint.pt
# logs/exp_formulation/20240111-120106_formulation-base_fold3/checkpoint.pt
# logs/exp_formulation/20240111-120202_formulation-base_fold4/checkpoint.pt
# logs/exp_formulation/20240111-120258_formulation-base_fold5/checkpoint.pt
# logs/exp_formulation/20240111-120339_formulation-base_fold6/checkpoint.pt
# logs/exp_formulation/20240111-120448_formulation-base_fold7/checkpoint.pt
# logs/exp_formulation/20240111-120520_formulation-base_fold8/checkpoint.pt
# logs/exp_formulation/20240111-120601_formulation-base_fold9/checkpoint.pt
# logs/exp_formulation/20240111-120638_formulation-base_fold10/checkpoint.pt
# logs/exp_formulation/20240111-120709_formulation-base_fold11/checkpoint.pt
# logs/exp_formulation/20240111-120805_formulation-base_fold12/checkpoint.pt
# logs/exp_formulation/20240111-120907_formulation-base_fold13/checkpoint.pt
# ...
